# %% [markdown]
# # DX 602 Week 10 Homework

# %% [markdown]
# ## Introduction
#
# In this homework, you will practice exploratory analysis using Pandas, and review previous material in this module.
#
# The first ten problems of this homework will be manually graded due to their visual nature.
# The remaining problems will be graded automatically like usual.

# %% [markdown]
# ## Example Code
#
# You may find it helpful to refer to this GitHub repository of Jupyter notebooks for example code.
#
# * https://github.com/bu-cds-omds/dx602-examples
#
# Any calculations demonstrated in code examples or videos may be found in these notebooks, and you are allowed to copy this example code in your homework answers.

# %% [markdown]
# ## Submission
#
# To submit your homework, take the following steps.
#
# 1. Save and commit this notebook.
# 2. Push your changes to GitHub.
# 3. Confirm that your changes are visible in GitHub.
# 4. Delete the codespace to avoid wasting your free quota.
#
# The auto-grading process usually completes within a few minutes of pushing to GitHub, but occasionally can take several minutes to an hour.
# If you submit your homework early enough, you may review the auto-grading results and fix any mistakes before the deadline.

# %% [markdown]
# ## Shared Imports
#
# Do not install or use any additional modules.
# Installing additional modules may result in an autograder failure resulting in zero points for some or all problems.

# %%
import math
import sys

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Shared Data

# %% [markdown]
# The following red wine data set is from the paper ["Modeling wine preferences by data mining from physicochemical properties"](https://repositorium.sdum.uminho.pt/bitstream/1822/10029/1/wine5.pdf).

# %%
red_wine = pd.read_csv("https://github.com/EpistasisLab/pmlb/raw/refs/heads/master/datasets/wine_quality_red/wine_quality_red.tsv.gz", sep="\t")
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  target
# 0      9.4       5
# 1      9.8       5
# 2      9.8       5
# 3      9.8       6
# 4      9.4       5

# %% [markdown]
# ## Problems

# %% [markdown]
# ### Problem 1 (manually graded)
#
# Plot histograms of every column of the red wine data set in the `red_wine` variable above.
# Make sure to adjust the spacing for legibility so that the labels do not overlap the charts.

# %%
# YOUR CHANGES HERE

red_wine.hist(figsize=(15, 10))
plt.tight_layout() # Adjust spacing to prevent labels from overlapping
plt.show()

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 2 (manually graded)
#
# Plot a scatter plot of the fixed acidity and citric acid columns of the red wine data set in the `red_wine` variable above.
# Make sure that both axes are labeled.

# %%
# YOUR CHANGES HERE

# Create the scatter plot
plt.figure(figsize=(8, 6)) # Optional: Adjusts the figure size
plt.scatter(x=red_wine['fixed acidity'], y=red_wine['citric acid'], alpha=0.5)

# Add labels to the axes
plt.xlabel('Fixed Acidity')
plt.ylabel('Citric Acid')

# Add a title
plt.title('Scatter Plot of Fixed Acidity vs. Citric Acid in Red Wine')

# Display the plot
plt.show()

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 3 (manually graded)
#
# Repeat the scatter plot of the fixed acidity and citric acid columns of the red wine data set.
# This time, make the y axis start from zero.

# %%
# YOUR CHANGES HERE

# Create the scatter plot
plt.figure(figsize=(8, 6)) # Optional: Adjusts the figure size
plt.scatter(x=red_wine['fixed acidity'], y=red_wine['citric acid'], alpha=0.5)

# Start y-axis at 0
plt.ylim(bottom=0)

# Add labels to the axes
plt.xlabel('Fixed Acidity')
plt.ylabel('Citric Acid')

# Add a title
plt.title('Scatter Plot of Fixed Acidity vs. Citric Acid in Red Wine')

# Display the plot
plt.show()

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 4 (manually graded)
#
# Plot a histogram of the `target` column of the red wine data set.
# (This column was supposed to represent the quality of the wine.)

# %%
# YOUR CHANGES HERE

# Plot a histogram of the 'quality' column using matplotlib
plt.figure(figsize=(8, 6))
plt.hist(red_wine['target'], bins=range(3, 10), align='left', rwidth=0.8, color='#ff7f0e', edgecolor='black')
plt.title('Histogram of Red Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Frequency')
plt.xticks(range(3, 10)) # Ensure all relevant quality scores are shown
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 5 (manually graded)
#
# In the video "Using Subplots with Pandas", the following chart plotted the average of each input column as a function of the abalone target column "Rings".
# Reproduce that chart with the red wine data set using its target column instead.
#
# ![](data:image/png;base64,...)

# %%
# YOUR CHANGES HERE

# Create a figure and a single subplot
fig, ax = plt.subplots(figsize=(6, 4))

# Plot a histogram of the 'target' column on the created subplot
red_wine['target'].plot(kind='hist', ax=ax, title='Distribution of Wine Classes (Target)')

# Set x-axis labels to reflect the wine classes
ax.set_xticks([0, 1, 2])
# ax.set_xticklabels(red_wine.target)
ax.set_xlabel('Wine Class')
ax.set_ylabel('Count')

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 6 (manually graded)
#
# Plot the correlation matrix of the red wine data set as a heat map.

# %% [markdown]
# Hint: this visualization was performed for the Palmer penguins data set in the video "Quick Visualizations pf the Palmer Penguins.

# %%
# YOUR CHANGES HERE

import seaborn as sns

# Calculate the correlation matrix
correlation_matrix = red_wine.corr()

# Plot the correlation heatmap
plt.figure(figsize=(10, 8)) # Adjust figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Red Wine Dataset')
plt.show()

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 7 (manually graded)
#
# Plot a box plot of the alcohol column grouping the data by the target column.

# %%
# YOUR CHANGES HERE

import seaborn as sns

# Create the box plot
plt.figure(figsize=(8, 6)) # Optional: Adjust figure size
sns.boxplot(x='target', y='alcohol', data=red_wine)

# Add title and labels for clarity
plt.title('Alcohol Content by Target Group')
plt.xlabel('Target Group')
plt.ylabel('Alcohol Content')

# Display the plot
plt.show()

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 8 (manually graded)
#
# Hexagonal bin plots are an alternative to scatter plots that helps visualize density instead of individual points.
# Make a hexagonal bin plot of the residual sugar and alcohol in the red wine data set.

# %% [markdown]
# Hint: pandas has built-in support for hexagonal bin plots.
# The default grid size that pandas uses is fairly small, so you may want to adjust it to your taste.

# %%
# YOUR CHANGES HERE

# Create the hexagonal bin plot using matplotlib's hexbin function
plt.figure(figsize=(10, 6)) # Optional: adjust figure size
plt.hexbin(x=red_wine['residual sugar'], y=red_wine['alcohol'], gridsize=50, cmap='viridis') # gridsize and cmap are customizable
plt.xlabel('Residual Sugar')
plt.ylabel('Alcohol')
plt.title('Hexagonal Bin Plot of Residual Sugar vs Alcohol in Red Wine Data Set')
plt.colorbar(label='Count / Density') # Color bar shows the density of points
plt.grid(True, linestyle='--', alpha=0.6) # Optional: add a grid

# Display the plot
plt.show()

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 9 (manually graded)
#
# Make a scatter plot of the red wine data set's target column and each of the other columns in that data set.
# Make one chart for each of the other columns.

# %%
# YOUR CHANGES HERE

# Define the target column name
target_column = 'target'

# Get all other column names
other_columns = [col for col in red_wine.columns if col != target_column]

# Create a scatter plot for each of the other columns against the target column
for col in other_columns:
    plt.figure(figsize=(8, 6)) # Create a new figure for each plot
    plt.scatter(red_wine[col], red_wine[target_column], alpha=0.7)
    plt.xlabel(col)
    plt.ylabel(target_column)
    plt.title(f'Scatter Plot of {col} vs {target_column}')
    plt.grid(True)
    plt.show()

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 10 (manually graded)
#
# Pick a pair of input columns in the red wine data set that looks interesting when colored by the target column.
# By interesting, the target values (colors) should be visibly different for some combination of your chosen input columns.

# %% [markdown]
# Hint: use scatter matrix to investigate possible columns, but don't leave it in your notebook as it will make the autograder very slow.

# %%
# YOUR CHANGES HERE

import seaborn as sns

# Set the style for better visualization
sns.set_style("whitegrid")

# Create a scatter plot of 'volatile acidity' vs 'alcohol' colored by 'quality'
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(data=red_wine, x='volatile acidity', y='alcohol', hue='volatile acidity', palette='viridis', s=100, alpha=0.7)

# Add title and labels
plt.title('Alcohol vs Volatile Acidity colored by Wine Quality')
plt.xlabel('Volatile Acidity')
plt.ylabel('Alcohol (%)')

# Add a legend
plt.legend(title='Quality', loc='best')

# Display the plot
plt.show()

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 11 (automatically graded)
#
# Set `p11` to the value of $(3 + \mathrm{sin}(2))^5$.

# %%
# YOUR CHANGES HERE

p11 = 898.39765

# %%
p11
# Out:
# 898.39765

# %% [markdown]
# ### Problem 12 (automatically graded)
#
# Write a function `p12` that takes in a sequence of strings and returns a list of the strings starting with the prefix "input_".
# The list should be in the same order as the input sequence.

# %%
# YOUR CHANGES HERE

def p12(column_names):
    result = []
    for s in column_names:
        if s.startswith("input_"):
            result.append(s)
    return result

# %%
# should return ["input_0", "input_1"]
p12(["input_0", "input_1", "target"])
# Out:
# ['input_0', 'input_1']

# %% [markdown]
# ### Problem 13 (automatically graded)
#
# Sort the list `p13` so that the tuples are sorted in order of their second entry (the strings).

# %%
# DO NOT CHANGE

p13 = [(0, "zebra"), (1, "yellow"), (2, "xylophone"), (3, "dog"), (4, "elephant"), (5, "apple")]

# %%
# YOUR CHANGES HERE

# Sort the list based on the second element (index 1) of each tuple
sorted_p13 = sorted(p13, key=lambda item: item[1])
sorted_p13
# Out:
# [(5, 'apple'),
#  (3, 'dog'),
#  (4, 'elephant'),
#  (2, 'xylophone'),
#  (1, 'yellow'),
#  (0, 'zebra')]

# %% [markdown]
# ### Problem 14 (automatically graded)
#
# Set `p14` to be a string with the value of the mathematical constant $\pi$ showing exactly 8 digits after the decimal point (include zeros as necessary).
# For your convenience, `q14` has a copy of $\pi$.

# %%
# DO NOT CHANGE

q14 = math.pi
q14
# Out:
# 3.141592653589793

# %%
# YOUR CHANGES HERE

p14 = f"{q14:.8f}"

# %% [markdown]
# ### Problem 15 (automatically graded)
#
# Plot the data in variables `x15` and `y15` as a line chart and save it to the file `p15.png`.

# %%
# DO NOT CHANGE

x15 = np.linspace(-10, 10)
y15 = x15 ** 2 - 2 * x15 + 1

# %%
# YOUR CHANGES HERE

# Create the plot
plt.figure(figsize=(8, 6))  # Optional: set the figure size
plt.plot(x15, y15, label='$y = x^2 - 2x + 1$') # Plot the line, add a label

# Add labels and a title (optional, but recommended)
plt.xlabel('x15')
plt.ylabel('y15')
plt.title('Plot of y15 vs. x15')
plt.legend() # Show the legend

# Add grid lines (optional)
plt.grid(True)

# Save the plot to a file named 'p15.png'
plt.savefig('p15.png')

# Display the plot (optional, helpful when running in a notebook)
plt.show()

# %% [markdown]
# ### Problem 16 (automatically graded)
#
# Set `p16` to be a $253 \times 512$ NumPy array filled entirely with the number 42.

# %%
# YOUR CHANGES HERE

p16 = np.full((253, 512), 42)

# %% [markdown]
# ### Problem 17 (automatically graded)
#
# Set `p17` to be a view of array `q17` that has size $1000000 \times 3$ where each row is a copy of `q17`.

# %% [markdown]
# Hint: use broadcasting.

# %%
# DO NOT CHANGE

q17 = np.array([1, 3, 5])
q17
# Out:
# array([1, 3, 5])

# %%
# YOUR CHANGES HERE

p17 = np.lib.stride_tricks.as_strided(q17, shape=(1000000, 3), strides=(0, q17.itemsize))

# %%
p17
# Out:
# array([[1, 3, 5],
#        [1, 3, 5],
#        [1, 3, 5],
#        ...,
#        [1, 3, 5],
#        [1, 3, 5],
#        [1, 3, 5]], shape=(1000000, 3))

# %% [markdown]
# ### Problem 18 (automatically graded)
#
# Set `p18` to be a Pandas series with the mean of each column of the red wine data set.
# The index of `p18` should be the column names of the red wine data set.

# %%
# YOUR CHANGES HERE

df_red_wine = pd.DataFrame(red_wine)

# Calculate the mean of each column and store it in p18
p18 = df_red_wine.mean()

# %%
p18
# Out:
# fixed acidity            8.319637
# volatile acidity         0.527821
# citric acid              0.270976
# residual sugar           2.538806
# chlorides                0.087467
# free sulfur dioxide     15.874922
# total sulfur dioxide    46.467792
# density                  0.996747
# pH                       3.311113
# sulphates                0.658149
# alcohol                 10.422983
# target                   5.636023
# dtype: float64

# %% [markdown]
# ### Problem 19 (automatically graded)
#
# The data frame in `q19` contains the first names of actors and their hometowns.
# Set `p19` to be a data frame of pairs of actors with the same hometown.
# `p19` should have two columns, `name_1` and `name_2` and the value in `name_1` should before the value in `name_2` to avoid matching an actor with themselves and repeating a pair with both orders.

# %%
# DO NOT CHANGE

q19 = pd.DataFrame({"name": ["Mel", "John", "Tom", "Benjamin", "Michael", "Emily", "Tom"],
                    "hometown": ["Peekskill", "Newton", "Concord", "Newton", "Newton", "London", "London"]})
q19
# Out:
#        name   hometown
# 0       Mel  Peekskill
# 1      John     Newton
# 2       Tom    Concord
# 3  Benjamin     Newton
# 4   Michael     Newton
# 5     Emily     London
# 6       Tom     London

# %%
# YOUR CHANGES HERE

# Group by hometown
grouped = q19.groupby("hometown")

# Initialize an empty list to store the pairs
pairs_list = []

# Iterate over each group (hometown)
for hometown, actors in grouped:
    names = sorted(actors["name"].unique()) # Get unique sorted names to handle repeated names
    
    # Generate all unique pairs within the group
    for i in range(len(names)):
        for j in range(i + 1, len(names)):
            pairs_list.append({"name_1": names[i], "name_2": names[j]})

# Create the final DataFrame from the list of pairs
p19 = pd.DataFrame(pairs_list, columns=["name_1", "name_2"])

# Reset the index for the final output
p19 = p19.reset_index(drop=True)

# %% [markdown]
# ### Problem 20 (automatically graded)
#
# Set `p20` to be a data frame with data from the red wine data set indexed on its target where each column has the mean values for that column and target value.
# `p20` should have a column for each of the input columns of the red wine data set.

# %%
# YOUR CHANGES HERE

# Combine features and target into a single DataFrame
red_wine_20 = pd.concat([red_wine, red_wine['target']], axis=1)

# Group by the 'target' column and calculate the mean of all other columns
p20 = red_wine_20.groupby(red_wine['target']).mean()
